# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
adult=pd.read_csv("data/adult.csv")
adult
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
adult.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
plt.figure(figsize=(15,10))
#Age histogramme
plt.subplot(2,3,1)
sns.histplot(x='age',data=adult,kde=True)
# Eduction num
plt.subplot(2,3,2)
sns.histplot(x='educational-num',data=adult,kde=True)
# Capital gain
plt.subplot(2,3,3)
sns.histplot(x='capital-gain',data=adult,kde=True)
# Capital loss
plt.subplot(2,3,4)
sns.histplot(x='capital-loss',data=adult,kde=True)
plt.subplots_adjust(wspace=0.7, hspace=1)

# %%
adult=adult[0:1400]

# %%
plt.figure(figsize=(15,10))
#Age histogramme
plt.subplot(2,3,1)
sns.histplot(x='age',data=adult,kde=True)
# Eduction num
plt.subplot(2,3,2)
sns.histplot(x='educational-num',data=adult,kde=True)
# Capital gain
plt.subplot(2,3,3)
sns.histplot(x='capital-gain',data=adult,kde=True)
# Capital loss
plt.subplot(2,3,4)
sns.histplot(x='capital-loss',data=adult,kde=True)
plt.subplots_adjust(wspace=0.7, hspace=1)

# %%
sns.boxplot(x="gender",y="age",data=adult)
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.boxplot(x="income",y="age",data=adult)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="marital-status",y="age",data=adult)
# Out:
# <Axes: xlabel='marital-status', ylabel='age'>

# %%
adult.describe()
# Out:
#                age         fnlwgt  educational-num  capital-gain  \
# count  1400.000000    1400.000000      1400.000000   1400.000000
# mean     38.584286  185955.655714         9.997143   1617.819286
# std      13.725223   99972.465835         2.719162   9923.637488
# min      17.000000   13769.000000         1.000000      0.000000
# 25%      27.000000  113747.000000         9.000000      0.000000
# 50%      37.000000  177010.000000        10.000000      0.000000
# 75%      48.000000  236737.250000        13.000000      0.000000
# max      90.000000  662460.000000        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count   1400.000000     1400.000000
# mean      83.619286       40.527857
# std      392.148168       12.080588
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     3004.000000       99.000000
