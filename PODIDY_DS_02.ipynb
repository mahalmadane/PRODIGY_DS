# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
adult=pd.read_csv("data/adult.csv")
adult
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
adult.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
plt.figure(figsize=(15,10))
#Age histogramme
plt.subplot(2,3,1)
sns.histplot(x='age',data=adult,kde=True)
# Eduction num
plt.subplot(2,3,2)
sns.histplot(x='educational-num',data=adult,kde=True)
# Capital gain
plt.subplot(2,3,3)
sns.histplot(x='capital-gain',data=adult,kde=True)
# Capital loss
plt.subplot(2,3,4)
sns.histplot(x='capital-loss',data=adult,kde=True)
# hours-per-week 
plt.subplot(2,3,5)
sns.histplot(x='hours-per-week',data=adult,kde=True)
plt.subplots_adjust(wspace=0.7, hspace=1)

# %%
sns.boxplot(x="gender",y="age",data=adult)
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.boxplot(x="income",y="age",data=adult)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="marital-status",y="age",data=adult)
# Out:
# <Axes: xlabel='marital-status', ylabel='age'>

# %%
plt.figure(figsize=(15,10))
sns.violinplot(x="marital-status",y="age",data=adult)
# Out:
# <Axes: xlabel='marital-status', ylabel='age'>

# %%
sns.barplot(data=adult["marital-status"])
# Out:
# <Axes: ylabel='marital-status'>

# %%
adult["marital-status"].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
adult.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
adult.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
corr_matrix = adult[["age","educational-num","fnlwgt","capital-gain","capital-loss","hours-per-week"]].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
cap=adult["capital-loss"]+54+adult["age"]**2
data=pd.DataFrame({
    "cap":cap,"age":adult['age']
})

corr=data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(x="age",y='cap',data=data)
# Out:
# <Axes: xlabel='age', ylabel='cap'>

# %%
sns.lineplot(x="age",y='cap',data=data)
# Out:
# <Axes: xlabel='age', ylabel='cap'>

# %%
sns.pairplot(adult)
plt.show()
